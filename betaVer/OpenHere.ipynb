# %% [markdown]
# # The Notebook

# %%
# This imports the functions I implemented
from helperFunctions import loadTable, plotData, plotMultiple
# import pandas as pd

# %% [markdown]
# ### This code cell helps you understand what this script sees in its current folder and subfolders
# We are going to be using ***relative paths***.
# They allow for more flexibility and ease of use of the notebook between different devices.
#
# The opposite of those are ***absolute paths*** such as "C:/Users/Uporabnik/Documents" which define the hard drive/partition etc.
# Relative paths ignore that, and just look from the perspective of this file.
#
# The cell below tells you which files are located in the same folder as this notebook.
# Then goes to subfolders and their files, then subsubfolders and their files etc.

# %%
import os
for root, dirs, files in os.walk(".", topdown=True):
    print("Files: ")
    for name in files:
        print("\t", os.path.join(root, name))
    print("Dirs: ")
    for name in dirs:
        print("\t", os.path.join(root, name))
# Out:
# Files:
# 	 .\helperFunctions.py
# 	 .\main.ipynb
# 	 .\main.py
# 	 .\OpenHere.ipynb
# Dirs:
# 	 .\__pycache__
# Files:
# 	 .\__pycache__\helperFunctions.cpython-310.pyc
# Dirs:

# %% [markdown]
# What if you want to see a superfolder, not a subfolder?
# ### You can backout one or more levels above, to see more subfolders
# You move one folder above by adding `../` to your ***relative path***.
# You could also chain this, such as `../../../` to back out three levels of folders.
#
# Just play around with the value of `howManyFoldersAbove` variable, and see what the cell outputs.

# %%
howManyFoldersAbove = 1 # 0
relativePath = "../" * howManyFoldersAbove
relativePath
# Out:
# '../'

# %% [markdown]
# Now you can define the rest of the relative path - which specific subfolders you want to go to from the previous cell (after you backed out).
# Playing with these two cells allows you to easily navigate through your folders on your PC and find the ***relative path*** of your data.

# %%
nameOfSubfolders = "data" #""
relativePath += nameOfSubfolders
relativePath
# Out:
# '../data'

# %% [markdown]
# So... which types of files are we looking for at this location?
# ### Here is how to narrow your query to just specific file extensions that interest you (from the path defined above)

# %%
extension1 = ".dat"
extension2 = ".txt"
import os

print("The following files match the query: ")
for file in os.listdir(relativePath):
    #print("Found: {}".format(file))
    if file.endswith(extension1) or file.endswith(extension2): #This line checks which files match the condition of being ".dat" or ".txt"
        print("\t", os.path.join(relativePath, file))
# Out:
# The following files match the query:
# 	 ../data\BSFO13_RS800_10-150kVcm_RT.dat
# 	 ../data\BSFO13_RS800_12h_10-150kVcm_RT.dat
# 	 ../data\BSFO13_RS820_10-150kVcm_RT.dat

# %% [markdown]
# If any of these files seem interesting for you, here is the method to pick them, load data from them and visualize it.
# ### Choose (copy-paste) the path (from above) to the file you want (below)

# %%
firstTable = loadTable("../data\BSFO13_RS820_10-150kVcm_RT.dat")

# You can see the keys (column headers) and values (the rest of the columns) separately
namesOfVariables, measuredVariables = list(firstTable.keys()), list(firstTable.values())
# Out:
# The following measurements/columns have been detected from ../data\BSFO13_RS820_10-150kVcm_RT.dat:
# 	 Time [s] - 6015 entries
# 	 V+ [V] - 6015 entries
# 	 V- [V] - 6015 entries
# 	 I1 [A] - 6015 entries
# 	 P1 [uC/cm2] - 6015 entries
# 	 I2 [A] - 6015 entries
# 	 P2 [uC/cm2] - 6015 entries
# 	 I3 [A] - 6015 entries
# 	 P3 [uC/cm2] - 6015 entries
# 	 D1 [nm] - 6015 entries
# 	 D2 [nm] - 6015 entries
# 	 D3 [nm] - 6015 entries
# 	 CH3 [V] - 6015 entries

# %% [markdown]
# ### From the output above, copy-paste the column title you find interesting
# This is how you take any column from the table into your variable

# %%
# Here are a few examples
time = firstTable["Time [s]"]
voltage = firstTable["V+ [V]"]
p1 = firstTable["P1 [uC/cm2]"]
john = firstTable["P2 [uC/cm2]"]
# You can name your variables however you want.
# But you need to copy paste the column titles from above

# %%
# You can type the name of any of the variables from above to see the values at that column
time
# Out:
# [0.0,
#  2.5e-05,
#  5e-05,
#  7.5e-05,
#  0.0001,
#  0.000125,
#  0.00015,
#  0.000175,
#  0.0002,
#  0.000225,
#  0.00025,
#  0.000275,
#  0.0003,
#  0.000325,
#  0.00035,
#  0.000375,
#  0.0004,
#  0.000425,
#  0.00045,
#  0.000475,
#  0.0005,
#  0.000525,
#  0.00055,
#  0.000575,
#  0.0006,
#  0.000625,
#  0.00065,
#  0.000675,
#  0.0007,
#  0.000725,
#  0.00075,
#  0.000775,
#  0.0008,
#  0.000825,
#  0.00085,
#  0.000875,
#  0.0009,
#  0.000925,
#  0.00095,
#  0.000975,
#  0.001,
#  0.001025,
#  0.00105,
#  0.001075,
#  0.0011,
#  0.001125,
#  0.00115,
#  0.001175,
#  0.0012,
#  0.001225,
#  0.00125,
#  0.001275,
#  0.0013,
#  0.001325,
#  0.00135,
#  0.001375,
#  0.0014,
#  0.001425,
#  0.00145,
#  0.001475,
#  0.0015,
#  0.001525,
#  0.00155,
#  0.001575,
#  0.0016,
#  0.001625,
#  0.00165,
#  0.001675,
#  0.0017,
#  0.001725,
#  0.00175,
#  0.001775,
#  0.0018,
#  0.001825,
#  0.00185,
#  0.001875,
#  0.0019,
#  0.001925,
#  0.00195,
#  0.001975,
#  0.002,
#  0.002025,
# ...

# %% [markdown]
# You can even load from multiple files at once, and store them together in a `list`:

# %%
wantedFiles = [
    "../data\BSFO13_RS800_10-150kVcm_RT.dat",
    "../data\BSFO13_RS820_10-150kVcm_RT.dat"
]

# %% [markdown]
# Then load each one of them, using a for loop (and store in a new variable `loadedTables`):

# %%
loadedTables = {}
for file in wantedFiles:
    loadedTables[file] = loadTable(file)
# Out:
# The following measurements/columns have been detected from ../data\BSFO13_RS800_10-150kVcm_RT.dat:
# 	 Time [s] - 6015 entries
# 	 V+ [V] - 6015 entries
# 	 V- [V] - 6015 entries
# 	 I1 [A] - 6015 entries
# 	 P1 [uC/cm2] - 6015 entries
# 	 I2 [A] - 6015 entries
# 	 P2 [uC/cm2] - 6015 entries
# 	 I3 [A] - 6015 entries
# 	 P3 [uC/cm2] - 6015 entries
# 	 D1 [nm] - 6015 entries
# 	 D2 [nm] - 6015 entries
# 	 D3 [nm] - 6015 entries
# 	 CH3 [V] - 6015 entries
#
# The following measurements/columns have been detected from ../data\BSFO13_RS820_10-150kVcm_RT.dat:
# 	 Time [s] - 6015 entries
# 	 V+ [V] - 6015 entries
# 	 V- [V] - 6015 entries
# 	 I1 [A] - 6015 entries
# 	 P1 [uC/cm2] - 6015 entries
# 	 I2 [A] - 6015 entries
# 	 P2 [uC/cm2] - 6015 entries
# 	 I3 [A] - 6015 entries
# 	 P3 [uC/cm2] - 6015 entries
# 	 D1 [nm] - 6015 entries
# 	 D2 [nm] - 6015 entries
# 	 D3 [nm] - 6015 entries
# 	 CH3 [V] - 6015 entries

# %% [markdown]
# To access column data (from this list of tables) - copy-paste the [file name] and [column title] you find interesting in square brackets

# %%
# Here's how we get it from the group
myVariable1 = loadedTables["../data\BSFO13_RS800_10-150kVcm_RT.dat"]["V+ [V]"]
myVariable1
# Out:
# [-1.099051,
#  -0.3258397,
#  1.862344,
#  4.269106,
#  6.365319,
#  8.035123,
#  11.15018,
#  12.01375,
#  14.80153,
#  17.50451,
#  19.48009,
#  21.212,
#  23.07888,
#  25.71736,
#  27.86852,
#  29.68285,
#  31.54854,
#  34.15596,
#  35.73619,
#  39.03399,
#  40.14958,
#  42.10843,
#  43.74479,
#  46.28414,
#  49.15075,
#  50.32368,
#  52.74716,
#  53.89142,
#  56.22771,
#  58.48517,
#  60.04628,
#  61.34462,
#  64.01535,
#  65.82132,
#  67.46246,
#  69.30426,
#  70.91792,
#  72.83139,
#  75.0566,
#  76.54843,
#  78.28154,
#  79.99315,
#  81.55785,
#  83.57762,
#  85.32864,
#  86.46931,
#  88.46639,
#  90.13739,
#  92.00308,
#  93.67766,
#  94.97958,
#  95.95423,
#  98.13525,
#  99.34878,
#  100.7642,
#  102.0231,
#  103.6762,
#  105.2839,
#  105.8046,
#  108.2532,
#  108.9197,
#  110.0126,
#  111.3993,
#  112.3214,
#  113.5588,
#  115.8784,
#  116.2009,
#  117.0465,
#  118.3437,
#  119.6779,
#  120.158,
#  121.4337,
#  123.0414,
#  123.2874,
#  123.8416,
#  125.0922,
#  125.5843,
# ...

# %% [markdown]
# ### Setting up interesting measurements for plotting
# Using Python dictionaries - key:value pairs (x axis: y axes)

# %%
# Independent variable
x_axis = "V+ [V]" 

# Dependent variables
y_axes = ["P1 [uC/cm2]", "P2 [uC/cm2]"]

# Pair them up
plots = {
    x_axis: y_axes
    # you can pair up another x axis here; then a ":"; then y_axes
    }

# Let's see what we have stored in memory
plots
# Out:
# {'V+ [V]': ['P1 [uC/cm2]', 'P2 [uC/cm2]']}

# %% [markdown]
# #### Plotting data
# As a reminder, let's check which files we're loading the data from

# %%
wantedFiles # See the entire list
# Out:
# ['../data\\BSFO13_RS800_10-150kVcm_RT.dat',
#  '../data\\BSFO13_RS820_10-150kVcm_RT.dat']

# %%
wantedFiles[0] # See the first element of the list
# Out:
# '../data\\BSFO13_RS800_10-150kVcm_RT.dat'

# %% [markdown]
# Let's plot from the first element of the list (in this case `../data\BSFO13_RS800_10-150kVcm_RT.dat`).
# We are using the `plotData` method from my `helperFunctions.py` script.

# %% [markdown]
# Pro tip:
# <sup><sub>
# To go through all independent variables (x axes) - we are using a `for` loop to go through `plots` variable
# In this case, there is only one x_axis in the `plots` dictionary (so `for` loop has only one iteration)</sub></sup>

# %%
for x_axis in plots:
    print(wantedFiles[0])
    plotData(loadedTables[wantedFiles[0]], x_axis, plots[x_axis], fileName=wantedFiles[0])
# Out:
# ../data\BSFO13_RS800_10-150kVcm_RT.dat
# V+ [V] P1 [uC/cm2]
# V+ [V] P2 [uC/cm2]

# %% [markdown]
# Let's repeat the same procedure for the second element of the list (in this case `../data\\BSFO13_RS820_10-150kVcm_RT.dat`)

# %%
for x_axis in plots:
    print(wantedFiles[1])
    plotData(loadedTables[wantedFiles[1]], x_axis, plots[x_axis], fileName=wantedFiles[1])
# Out:
# ../data\BSFO13_RS820_10-150kVcm_RT.dat
# V+ [V] P1 [uC/cm2]
# V+ [V] P2 [uC/cm2]

# %% [markdown]
# ## Combine plot data from two different files
# You can also combine data from two files together on the same plot using the `plotMultiple()` function from my `helperFunctions.py` script.

# %%
plotMultiple(loadedTables, "V+ [V]", ["P1 [uC/cm2]", "P2 [uC/cm2]"])
# Out:
# V+ [V] P1 [uC/cm2]
# V+ [V] P2 [uC/cm2]
# V+ [V] P1 [uC/cm2]
# V+ [V] P2 [uC/cm2]
